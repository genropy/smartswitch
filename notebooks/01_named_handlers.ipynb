# %% [markdown]
# # SmartSwitch Tutorial 01: Named Handlers
#
# **Welcome!** This is the first tutorial in the SmartSwitch series.
#
# In this notebook you'll learn:
# - ✅ How to register functions by name
# - ✅ How to call them dynamically
# - ✅ When this pattern is useful
#
# **Time**: ~5 minutes
#
# ---

# %% [markdown]
# ## The Problem
#
# You have several operations and want to call them by name.
#
# **Traditional approach** - Manual dictionary:

# %%
# Traditional: Manual dictionary (ugly!)
def save_data(data):
    return f"Saving: {data}"

def load_data(data):
    return f"Loading: {data}"

def delete_data(data):
    return f"Deleting: {data}"

# Manual registration - easy to forget!
operations = {
    'save_data': save_data,
    'load_data': load_data,
    'delete_data': delete_data
}

# Call by name
op = operations.get('save_data')
if op:
    result = op('my_file.txt')
    print(result)

# %% [markdown]
# **Problems with this approach:**
# - ❌ Easy to forget to add functions to the dict
# - ❌ Function name repeated twice (definition + dict)
# - ❌ Boilerplate for every function
# - ❌ Manual error handling with `.get()`

# %% [markdown]
# ## The SmartSwitch Solution
#
# Let's see how SmartSwitch makes this cleaner:

# %%
# Install if needed (uncomment if running on Colab/Binder)
# !pip install smartswitch

# %%
from smartswitch import Switcher

# Create a switcher
ops = Switcher()

# Register functions with @decorator
@ops
def save_data(data):
    return f"Saving: {data}"

@ops
def load_data(data):
    return f"Loading: {data}"

@ops
def delete_data(data):
    return f"Deleting: {data}"

# Call by name - clean and simple!
result = ops('save_data')('my_file.txt')
print(result)

# %% [markdown]
# **Benefits:**
# - ✅ Automatic registration with `@ops` decorator
# - ✅ No manual dictionary management
# - ✅ Function name written only once
# - ✅ Clean, Pythonic syntax

# %% [markdown]
# ## How It Works
#
# Let's break it down:
#
# ```python
# ops('save_data')  # ← Returns the function
#                   # ↓ Then call it with arguments
# ops('save_data')('my_file.txt')
# ```
#
# It's a **two-step call**:
# 1. `ops('name')` → retrieves the handler function
# 2. `(args)` → calls the handler with arguments

# %% [markdown]
# ## Try It Yourself!
#
# Add your own operations:

# %%
from smartswitch import Switcher

ops = Switcher()

@ops
def greet(name):
    return f"Hello, {name}!"

# Add your own functions here!
# @ops
# def ...

# Try calling them
print(ops('greet')('Alice'))
# print(ops('your_function')(...))

# %% [markdown]
# ## Custom Names
#
# You can register handlers with custom names different from the function name:

# %%
ops = Switcher()

# Register with alias
@ops('reset')
def destroy_all_data():
    return "💥 Everything deleted!"

@ops('clear')
def remove_cache():
    return "🗑️ Cache cleared!"

# Call with alias (not function name!)
print(ops('reset')())
print(ops('clear')())

# %% [markdown]
# ## Discovering Registered Handlers
#
# You can see what handlers are registered:

# %%
ops = Switcher()

@ops
def action_a():
    pass

@ops
def action_b():
    pass

@ops('custom')
def action_c():
    pass

# List all registered names
print("Registered handlers:", ops.entries())

# %% [markdown]
# ## Real-World Example: CLI Commands
#
# A common use case is building CLI tools:

# %%
from smartswitch import Switcher

cli = Switcher(name="mycli")

@cli
def start(port=8000):
    return f"🚀 Server starting on port {port}"

@cli
def stop():
    return "🛑 Server stopped"

@cli
def status():
    return "✅ Server is running"

# Simulate CLI call
command = "start"  # This would come from sys.argv

result = cli(command)(port=3000)
print(result)

# %% [markdown]
# ## When to Use Named Handlers
#
# This pattern is perfect when you need:
#
# ✅ **Command dispatching** - CLI tools, bots, menu systems
#
# ✅ **Plugin systems** - Load handlers by name dynamically
#
# ✅ **API routing** - Map endpoint names to handler functions
#
# ✅ **State machines** - Dispatch actions by state name
#
# ⚠️ **Not needed for**:
# - Simple functions you always call directly
# - When you know the function at compile time

# %% [markdown]
# ## Exercise: Build Your Own CLI
#
# Create a simple file manager CLI with these commands:
# - `list` - List files
# - `create` - Create a file
# - `delete` - Delete a file
# - `help` - Show available commands

# %%
from smartswitch import Switcher

file_cli = Switcher()

# TODO: Add your commands here!
@file_cli
def help():
    commands = file_cli.entries()
    return f"Available commands: {', '.join(commands)}"

# Test it
print(file_cli('help')())

# %% [markdown]
# ## Summary
#
# You learned:
#
# ✅ **Register handlers** with `@switcher` decorator
#
# ✅ **Call by name** with `switcher('name')(args)`
#
# ✅ **Custom aliases** with `@switcher('alias')`
#
# ✅ **Discovery** with `switcher.entries()`
#
# ---
#
# ## Next Steps
#
# Continue to **Tutorial 02: Hierarchical Names** to learn how to organize handlers with prefixes and dot notation for complex APIs.
#
# 📖 **Documentation**: [Named Handlers Guide](https://smartswitch.readthedocs.io/guide/named-handlers/)
#
# ---
#
# **Questions?** Open an issue on [GitHub](https://github.com/genropy/smartswitch/issues)
